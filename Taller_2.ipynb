# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
shapefile_path = "MGN2024_MPIO_POLITICO/MGN_ADM_MPIO_GRAFICO.shp"
map=gpd.read_file(shapefile_path)
map.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 shapefile_path = "MGN2024_MPIO_POLITICO/MGN_ADM_MPIO_GRAFICO.shp"
# ----> 2 map=gpd.read_file(shapefile_path)
#       3 map.head()
#
# File ~/.venvs/global-ml/lib64/python3.13/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File ~/.venvs/global-ml/lib64/python3.13/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
# ...

# %%
df = pd.read_csv("DBF-ENCV-Tecnologias_informacion_comunicacion-2024/Tecnologias de informacion y comunicacion.CSV", sep=';')
df.head()
# Out:
#    DIRECTORIO  SECUENCIA_ENCUESTA  SECUENCIA_P  ORDEN       FEX_C  P1910  \
# 0     8219789                   1            1      1  651.298866      5
# 1     8219789                   2            1      2  651.298866      5
# 2     8219789                   3            1      3  651.298866      5
# 3     8219789                   4            1      4  651.298866      5
# 4     8219789                   5            1      5  651.298866      5
#
#    P1911  P1912  P1084  P1710  ...  P1080S4  P1080S5  P1080S6  P804  P805  \
# 0      5      5      1    NaN  ...      1.0      NaN      NaN     5   NaN
# 1      5      5      1    NaN  ...      1.0      NaN      NaN     5   NaN
# 2      2      5      1    NaN  ...      1.0      NaN      NaN     5   NaN
# 3      5      2      2    NaN  ...      NaN      NaN      NaN     5   NaN
# 4      5      5      1    NaN  ...      1.0      NaN      NaN     5   NaN
#
#    P805S1  P805S2  P805S3  P805S4  P805S5
# ...
